# %% [markdown]
# # Dictionaries, Nesting and the secret Auction

# %%
#This is the usual form of a dictionary 
programming_dictionary = {
    "Bug": "An error in a program that prevents...",
    "function": "A pice of code...",
    "Loop": "The action that...",                     
}

# %% [markdown]
# # How we can get the data of a Dictionary

# %%
#We just need to call the dictionary and the key of the value we wanted to print 
# Like this ["key"]

programming_dictionary["Bug"]
# Out:
# 'An error in a program that prevents...'

# %%
#If we spell the key in a wrong way then we are going to receive an error
programming_dictionary["Booog"]
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# Cell In[22], line 2
#       1 #If we spell the key in a wrong way then we are going to receive an error
# ----> 2 programming_dictionary["Booog"]
#
# KeyError: 'Booog'

# %%
#This will work also wih numbers like
programming_dictionary2 = {
    "Bug": "An error in a program that prevents...",
    123456: "A pice of code...",
    "Loop": "The action that...",                     
}

programming_dictionary2[123456]
# Out:
# 'A pice of code...'

# %% [markdown]
# # How we can add an element in our dictionary

# %%
#We can add an element putting a new key inside and the value of that key
programming_dictionary["NewKey"] = "Definition of new key is that ...."

programming_dictionary
# Out:
# {'Bug': 'An error in a program that prevents...',
#  'function': 'A pice of code...',
#  'Loop': 'The action that...',
#  'NewKey': 'Definition of new key is that ....'}

# %% [markdown]
# # How we can create an empty directionary

# %%
empty_dictionary = {}

# %% [markdown]
# # How we can wipe an existing dictionary

# %%
#If we have a dictionary that has some keys but we wanted to clear it we do it like
programming_dictionary2 = {}
#WE can verify
programming_dictionary2
# Out:
# {}

# %% [markdown]
# # Edit an item in a dictionary

# %%
#As we see above for add a new element to a dictionary we put the newKey, so foor edit the value of a key we can do quit almost the same

programming_dictionary["Bug"] = "The new value of the key is ....."

programming_dictionary
# Out:
# {'Bug': 'The new value of the key is .....',
#  'function': 'A pice of code...',
#  'Loop': 'The action that...',
#  'NewKey': 'Definition of new key is that ....'}

# %%
#How about editing a key and not the value??

# %% [markdown]
# # How we can loop through a dictionary

# %%
#This will print the key but not the value
for key in programming_dictionary:
    print(key)

print("-"*30)
#How we can print both?

for key in programming_dictionary:
    print(key)
    #Now with the key we can get into the dictionary and print the value of each of them
    print(programming_dictionary[key])
# Out:
# Bug
# function
# Loop
# NewKey
# ------------------------------
# Bug
# The new value of the key is .....
# function
# A pice of code...
# Loop
# The action that...
# NewKey
# Definition of new key is that ....

# %% [markdown]
# # Coding excercise
#
# ## Grading Program
# * You have access to a database of student_scores in the format of a dictionary. The keys in student_scores are the names of the students and the values are their exam scores.
#
# > * Write a program that converts their scores to grades.
#
# * By the end of your program, you should have a new dictionary called student_grades that should contain student names as keys and their assessed grades for values.
# * The final version of the student_grades dictionary will be checked.
#
# > * **DO NOT** modify lines 1-7 to change the existing student_scores dictionary.
#
# * This is the scoring criteria:
#
# > - Scores 91 - 100: Grade = "Outstanding"
#
# > - Scores 81 - 90: Grade = "Exceeds Expectations"
#
# > - Scores 71 - 80: Grade = "Acceptable"
#
# > - Scores 70 or lower: Grade = "Fail"

# %%
student_scores = {
    'Harry': 88,
    'Ron': 78,
    'Hermione': 95,
    'Draco': 75,
    'Neville': 60
}

#Empty dictionary
student_grades = {}

for key in student_scores:
    if student_scores[key]>=91 and student_scores[key]<=100:
        student_grades[key]='Outstanding'
    elif student_scores[key]>=81 and student_scores[key]<=90:
            student_grades[key]='Exceeds Expectations'
    elif student_scores[key]>=71 and student_scores[key]<=80:
                student_grades[key]='Acceptable'
    else:
           student_grades[key]='Fail'

student_grades
# Out:
# {'Harry': 'Exceeds Expectations',
#  'Ron': 'Acceptable',
#  'Hermione': 'Outstanding',
#  'Draco': 'Acceptable',
#  'Neville': 'Fail'}

# %% [markdown]
# # Nesting
#
# WE can mix match varios data types to achive our desire strcuture

# %%
#Initial dictionary
capitals = {
    "France": "Paris",
    "Germany": "Berlin"
}

#Nested a list in a dictionary
travel_log = {
    "France": ["Paris","Lille","Dijon"],
    "Germany": ["Stuttgart","Berlin"]
}

# How we can print a value of the the dictionary as Lille

# %%
#We can pass the key that we want, and then the position of the value if we know it like a "matrix"
print(travel_log["France"][1])

#WE can not pass just numbers if we wanted to print the key only like
# print(travel_log[1]) this will only works for lists not dictionaries
# Out:
# Lille

# %%
#LISTS?
nested_list = ["A","B","C",["D","F"]]
# AS WE CAN SEE WE CAN HAVE A LIST INSIDE A LIST BUT WE CAN NOT HAVE A DICTIONARY INSIDE A LIST 
# FOR DICTIONARIES IS THE OPPOSITE WE CAN NESTED A LIST AND EVEN A DICTIONARY

#How we can print the element D
#This will give me D,f 
print(nested_list[3])

#I only one D
print(nested_list[3][0])


# WE have to be carefull if we know in which position we have a list because we can not use the same for other items
# print(nested_list[0][1])
# Out:
# ['D', 'F']
# D

# %% [markdown]
# # Nested a list in dictionary in other dictionary

# %%
travel_log = {
    "France": {
        "num_times_visited": 8,
        "cities_visited": ["Paris","Lille","Dijon"]
    },
    "Germany": 
    {
        "num_times_visited": 10,
        "cities_visited": ["Stuttgart","Berlin"]
    }
    
}

# %%
#How we can print the num_times for France and Berlin item?

print(travel_log["France"]["num_times_visited"])

print(travel_log["Germany"]["cities_visited"][1])

#We have to know if we are working first with a dictionary or a list
# With that we know that first we need the key, then another key if is necessary, and the index position of the value 
# (also have knowladge of the number of items on the list)
# Out:
# 8
# Berlin

# %% [markdown]
# # How we can change the starting_dictionary to the final_dictionary?

# %%
starting_dictionary = {
    "a": 9,
    "b": 8,
}


final_dictionary = {
    "a": 9,
    "b": 8,
    #"c": 7,
}

# %%
#This will convert final dioctionary into an int, wiping the dictionary
final_dictionary = starting_dictionary["c"] = 7

print(final_dictionary)
# Out:
# 7

# %%
#WE have to add the value on the dictionary first, and then we can copy all the elements on the new dictionary
starting_dictionary["c"] = 7
#EVen if its only one value, this will copy all
final_dictionary = starting_dictionary

print(final_dictionary)
# Out:
# {'a': 9, 'b': 8, 'c': 7}

# %% [markdown]
# # Test 2

# %%
dict = {
    "a": 1,
    "b": 2,
    "c": 3,
}

#What about this
for key in dict:
    dict[key] +=1
#Since the values are int we are adding the 1 to the value of the current key in each interaction
print(dict)

#We are declaring a new key with a new value, even if the key is not a str, the dictionary will accept it 
dict[1] = 4
print(dict)

#Now this will work, but is not a list but the same dictionary key
print(dict[1])
#This will print the value of 4, but if we have the dict like the begining then this will not work

dict["c"]= [1,2,3]

print(dict)


#Now this will not work, since we have a list inside the dictionary
# for key in dict:
#    dict[key] +=1
# Out:
# {'a': 2, 'b': 3, 'c': 4}
# {'a': 2, 'b': 3, 'c': 4, 1: 4}
# 4
# {'a': 2, 'b': 3, 'c': [1, 2, 3], 1: 4}

# %% [markdown]
# ## Which line of code will print "Steak"?

# %%
order = {
    "starter": {1: "Salad", 2: "Soup"},
    "main": {1: ["Burger", "Fries"], 2: ["Steak"]},
    "dessert": {1: ["Ice Cream"], 2: []},
}

# %%
#This will print not just only steak, but the list of the key 2 in key main
print(order["main"][2])
# Out:
# ['Steak']

# %%
#The keys can not be rest if they are strings
print(order["dessert"-1][2][0])
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# Cell In[52], line 1
# ----> 1 print(order["dessert"-1][2][0])
#
# TypeError: unsupported operand type(s) for -: 'str' and 'int'

# %%
print(order["main"][2][0])
# Out:
# Steak

# %% [markdown]
# # How to clean the screen, use the library os, and system, like this

# %%
from os import system

# %% [markdown]
# # The Secret Action Program

# %%
#Both are correct just to not use art.log4....
#import art 
from art import log4SecretAction 

print(log4SecretAction+"\nWelcome to the secret auction program")
# Out:
#                            ____         ___
#                          ,' __ ``.._..''   `.
#                          `.`. ``-.___..-.    :
#  ,---..____________________>/          _,'_  |
#  `-:._,:_|_|_|_|_|_|_|_|_|_|_|.:SSt:.:|-|(/  |
#                         _.' )   ____  '-'    ;
#                        (    `-''  __``-'    /
#                         ``-....-''  ``-..-''
#
# Welcome to the secret auction program

# %%
dic_binds = {}
answer = 'yes'
while answer == 'yes':
    print("What is your name? ")
    key = input("Put your name: ").lower()
    print("What is your bind? ")
    value = int(input("Bind: "))
    #Store the values inside the dictionary
    dic_binds[key] = value

    #We can clean the console here but for now there is no need, but we can do it like
    # print("\n"*100) to "simulated this"
    #Asked if is there another person
    print("Are there any others bidders? ")
    answer = input("Type 'yes' or 'no' ").lower()

#After have all the persons we need to compare the values of the dictionary
maxbindPerson = ''
maxbind = 0

for value in dic_binds:
    if maxbind<dic_binds[value]:
        maxbind = dic_binds[value]
        #ANd we save the key for later
        maxbindPerson = value
#How we can do this we want to print the key and the value of 
print(f"The winner is {maxbindPerson} with a bind of {dic_binds[maxbindPerson]}")
# Out:
# What is your name
# What is your bind
# Are there any others bidders?
# What is your name
# What is your bind
# Are there any others bidders?
# The winner is leon with a bind of 300
