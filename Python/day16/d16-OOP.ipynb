# %% [markdown]
# # Object Oriented Programming

# %% [markdown]
# ### Important
# When we are using turtle in JUpyter we need to restart the kernal, if we do not do that the turtle object will be there even if we excuted only once, the second time will produce an error

# %%
import turtle

# %%
timmy = turtle.Turtle()
# #print(timmy)

timmy.forward(100)

my_screen = turtle.Screen() #IF A SCREEN ALREADY EXISTS, IT DOES NOT CREATE ANOTHER ONE 
#THIS WILL  BE REPRESENTEND AS
'''
              ┌─────────────────┐
              │  Turtle Screen  │
              │                 │
              │     Timmy 🐢    │
              └─────────────────┘
                    ↑       ↑
                    │       │
             Turtle()    Screen()
'''
#This will gave us the address of where is timmy on the stack
print(timmy)

timmy.shape("turtle")
timmy.color("coral")
timmy.forward(100)
print(my_screen.canvheight)
my_screen.exitonclick()
# Out:
# ...
# 300

# %%
#Now we are gonna user prettyTable
from prettytable import PrettyTable

# %% [markdown]
# # Create a PrettyTable object and save it to a variable called table

# %%
table = PrettyTable()

print(table)
# Out:
# ++
# ||
# ++
# ++

# %%
table.add_column("New Column",["DAta1","Data2","Data3"])

print(table)
# Out:
# +------------+
# | New Column |
# +------------+
# |   DAta1    |
# |   Data2    |
# |   Data3    |
# +------------+

# %%
#New obj
table2 = PrettyTable()
# Out:
# ++
# ||
# ++
# ++

# %%
table2.add_column("Pokemon Name ",["Pikachu","Squirtle","Charmander"])
table2.add_column("Type ",["Electric","Water","Fire"])

print(table2)
# Out:
# +---------------+----------+
# | Pokemon Name  |  Type    |
# +---------------+----------+
# |    Pikachu    | Electric |
# |    Squirtle   |  Water   |
# |   Charmander  |   Fire   |
# +---------------+----------+

# %%
table2.align = "l"
print(table2)
# Out:
# +---------------+----------+
# | Pokemon Name  | Type     |
# +---------------+----------+
# | Pikachu       | Electric |
# | Squirtle      | Water    |
# | Charmander    | Fire     |
# +---------------+----------+
