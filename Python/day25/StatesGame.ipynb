# %% [markdown]
# # US STATE GAME

# %%
from pathlib import Path
import pandas as pd

# %%
#The difference between a py file and a ipynb file is that Path.cwd() will work fine
#and return the direction from the current working directory
folder_path = Path.cwd()

print(folder_path)
# Out:
# /run/media/diwsgen/HDD/Documentos/Estudio/Programacion/notes/CS-Fundamentals/Python/day25

# %%
import turtle

screen = turtle.Screen()

screen.title("States Game")


screen.exitonclick()
